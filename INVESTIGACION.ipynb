# %% [markdown]
# ## Empezamos importanto librerias standar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import userdata

# %%
import requests

# Configuración
API_TOKEN = userdata.get('CLASH_API')
BASE_URL = 'https://api.clashroyale.com/v1'
HEADERS = {
    'Authorization': f'Bearer {API_TOKEN}',
    'Accept': 'application/json'
}

def get_player_info(player_tag):
    formatted_tag = player_tag.replace('#', '%23')
    url = f"{BASE_URL}/players/{formatted_tag}"

    response = requests.get(url, headers=HEADERS)

    if response.status_code == 200:
        return response.json()
    else:
        return f"Error: {response.status_code} - {response.text}"

tag = "#8P8CLL2JL"
player_data = get_player_info(tag)

# %%
print("Cartas principales del jugador:")
for card in player_data['cards']:
    print(f"- {card['name']} (Nivel: {card['level']})")
# Out:
# Cartas principales del jugador:
# - Mortar (Nivel: 13)
# - Mirror (Nivel: 5)
# - Bowler (Nivel: 8)
# - Fisherman (Nivel: 3)
# - Three Musketeers (Nivel: 9)
# - Guards (Nivel: 6)
# - Royal Giant (Nivel: 12)
# - Goblin Drill (Nivel: 11)
# - Giant (Nivel: 9)
# - Prince (Nivel: 6)
# - Minion Horde (Nivel: 12)
# - Battle Ram (Nivel: 9)
# - Rascals (Nivel: 12)
# - Golden Knight (Nivel: 5)
# - Goblin Gang (Nivel: 14)
# - Lava Hound (Nivel: 3)
# - Cannon (Nivel: 15)
# - Musketeer (Nivel: 10)
# - Royal Ghost (Nivel: 3)
# - Goblin Cage (Nivel: 9)
# - P.E.K.K.A (Nivel: 10)
# - Goblin Barrel (Nivel: 6)
# - X-Bow (Nivel: 6)
# - Electro Dragon (Nivel: 7)
# - Archers (Nivel: 13)
# - Rocket (Nivel: 9)
# - Wizard (Nivel: 9)
# - Zap (Nivel: 13)
# - Lumberjack (Nivel: 2)
# - Giant Skeleton (Nivel: 6)
# - Freeze (Nivel: 7)
# - Ice Spirit (Nivel: 13)
# - Balloon (Nivel: 6)
# - Bats (Nivel: 13)
# - Skeleton Army (Nivel: 5)
# - Witch (Nivel: 6)
# - Bandit (Nivel: 4)
# - Ram Rider (Nivel: 3)
# - Lightning (Nivel: 8)
# - Earthquake (Nivel: 9)
# - Tesla (Nivel: 14)
# - Poison (Nivel: 11)
# - Dark Prince (Nivel: 7)
# - Skeleton Barrel (Nivel: 13)
# - Valkyrie (Nivel: 14)
# - Elixir Collector (Nivel: 9)
# - Executioner (Nivel: 6)
# - Elite Barbarians (Nivel: 11)
# - Princess (Nivel: 3)
# - Electro Spirit (Nivel: 15)
# - Dart Goblin (Nivel: 9)
# - Mega Minion (Nivel: 11)
# - Clone (Nivel: 5)
# - Goblin Giant (Nivel: 6)
# - Barbarian Barrel (Nivel: 8)
# - Golem (Nivel: 9)
# - Mini P.E.K.K.A (Nivel: 12)
# - Giant Snowball (Nivel: 15)
# - Minions (Nivel: 14)
# - Royal Delivery (Nivel: 16)
# - Phoenix (Nivel: 3)
# - Fire Spirit (Nivel: 11)
# - Baby Dragon (Nivel: 9)
# - Zappies (Nivel: 11)
# - Battle Healer (Nivel: 9)
# - Sparky (Nivel: 3)
# - Fireball (Nivel: 13)
# - Royal Hogs (Nivel: 12)
# - Goblins (Nivel: 12)
# - Bomber (Nivel: 11)
# - Ice Golem (Nivel: 9)
# - Mega Knight (Nivel: 4)
# - Firecracker (Nivel: 13)
# - Electro Giant (Nivel: 5)
# - Hog Rider (Nivel: 9)
# - Inferno Tower (Nivel: 10)
# - Hunter (Nivel: 10)
# - Skeleton Dragons (Nivel: 11)
# - Mother Witch (Nivel: 3)
# - Inferno Dragon (Nivel: 3)
# - Royal Recruits (Nivel: 15)
# - Skeletons (Nivel: 14)
# - Flying Machine (Nivel: 12)
# - Heal Spirit (Nivel: 9)
# - Cannon Cart (Nivel: 9)
# - Tombstone (Nivel: 8)
# - Barbarians (Nivel: 11)
# - Ice Wizard (Nivel: 4)
# - Graveyard (Nivel: 6)
# - Electro Wizard (Nivel: 3)
# - The Log (Nivel: 4)
# - Magic Archer (Nivel: 5)
# - Miner (Nivel: 6)
# - Tornado (Nivel: 8)
# - Knight (Nivel: 16)
# - Wall Breakers (Nivel: 6)
# - Spear Goblins (Nivel: 13)
# - Bomb Tower (Nivel: 8)
# - Little Prince (Nivel: 1)
# - Furnace (Nivel: 14)
# - Goblin Hut (Nivel: 10)
# - Barbarian Hut (Nivel: 9)
# - Arrows (Nivel: 14)
# - Night Witch (Nivel: 5)
# - Rage (Nivel: 6)
# - Skeleton King (Nivel: 2)
# - Elixir Golem (Nivel: 9)
# - Void (Nivel: 6)
# - Goblin Demolisher (Nivel: 9)
# - Archer Queen (Nivel: 1)
# - Goblin Machine (Nivel: 5)
# - Suspicious Bush (Nivel: 9)
# - Mighty Miner (Nivel: 2)
# - Berserker (Nivel: 11)
# - Goblin Curse (Nivel: 6)
# - Spirit Empress (Nivel: 2)
# - Rune Giant (Nivel: 6)
# - Vines (Nivel: 6)
# - Goblinstein (Nivel: 2)
# - Boss Bandit (Nivel: 1)
# - Monk (Nivel: 1)
